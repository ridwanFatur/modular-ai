# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import ast

# %%
cymbalair_policy = pd.read_csv("./data/cymbalair_policy.csv")
airport_dataset = pd.read_csv("./data/airport_dataset.csv")
flights_dataset = pd.read_csv("./data/flights_dataset.csv")
amenity_dataset = pd.read_csv("./data/amenity_dataset.csv")

# %%
cymbalair_policy.head(2)
# Out:
#    id                                            content  \
# 0   0  # Cymbal Air: Passenger Policy  \n## Ticket Pu...
# 1   1  Changes: Changes to tickets are permitted at a...
#
#                                            embedding
# 0  [-0.021210914477705956, -0.0011509297182783484...
# 1  [-0.023659581318497658, 0.0008153968374244869,...

# %%
airport_dataset.head(2)
# Out:
#    id iata            name    city           country
# 0   0  GKA  Goroka Airport  Goroka  Papua New Guinea
# 1   1  MAG  Madang Airport  Madang  Papua New Guinea

# %%
flights_dataset.head(2)
# Out:
#    id airline  flight_number departure_airport arrival_airport  \
# 0   0      UA           1532               SFO             DEN
# 1   1      UA           1158               SFO             ORD
#
#         departure_time         arrival_time departure_gate arrival_gate
# 0  2025-01-01 05:50:00  2025-01-01 09:23:00            E49           D6
# 1  2025-01-01 05:57:00  2025-01-01 12:13:00            C38          D30

# %%
amenity_dataset.head(2)
# Out:
#    id                   name                description       location  \
# 0   0        Coffee Shop 732  Serving American cuisine.  Near Gate B12
# 1   1  Electronics Store 145       Selling electronics.  Near Gate B10
#
#      terminal    category                      hour sunday_start_hour  \
# 0  Terminal 3  restaurant  Daily 7:00 am - 10:00 pm          07:00:00
# 1  Terminal 2        shop   Daily 9:00 am - 7:00 pm          09:00:00
#
#   sunday_end_hour monday_start_hour  ... wednesday_start_hour  \
# 0        22:00:00          07:00:00  ...             07:00:00
# 1        19:00:00          09:00:00  ...             09:00:00
#
#   wednesday_end_hour thursday_start_hour thursday_end_hour friday_start_hour  \
# 0           22:00:00            07:00:00          22:00:00          07:00:00
# 1           19:00:00            09:00:00          19:00:00          09:00:00
#
#   friday_end_hour saturday_start_hour saturday_end_hour  \
# ...

# %%
amenity_dataset.columns
# Out:
# Index(['id', 'name', 'description', 'location', 'terminal', 'category', 'hour',
#        'sunday_start_hour', 'sunday_end_hour', 'monday_start_hour',
#        'monday_end_hour', 'tuesday_start_hour', 'tuesday_end_hour',
#        'wednesday_start_hour', 'wednesday_end_hour', 'thursday_start_hour',
#        'thursday_end_hour', 'friday_start_hour', 'friday_end_hour',
#        'saturday_start_hour', 'saturday_end_hour', 'content', 'embedding'],
#       dtype='object')

# %%
embedding = cymbalair_policy.iloc[0]['embedding']

# %%
len(ast.literal_eval(embedding))
# Out:
# 3072

# %%
amenity_embedding = amenity_dataset.iloc[0]['embedding']

# %%
len(ast.literal_eval(amenity_embedding))
# Out:
# 3072

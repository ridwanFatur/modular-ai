# %%
from supabase import create_client
import os
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
SUPABASE_URL = os.environ["SUPABASE_URL"]
SUPABASE_KEY = os.environ["SUPABASE_KEY"]

# %%
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

# %%
supabase.storage.create_bucket("my-bucket-2")
# Out:
# {'name': 'my-bucket-2'}

# %%
res = supabase.storage.list_buckets()

print(res)
# Out:
# [SyncBucket(id='my-bucket', name='my-bucket', owner='', public=False, created_at=datetime.datetime(2026, 5, 25, 7, 16, 0, 464000, tzinfo=TzInfo(0)), updated_at=datetime.datetime(2026, 5, 25, 7, 16, 0, 464000, tzinfo=TzInfo(0)), file_size_limit=None, allowed_mime_types=None, type='STANDARD'), SyncBucket(id='my-bucket-2', name='my-bucket-2', owner='', public=False, created_at=datetime.datetime(2026, 5, 25, 7, 17, 10, 658000, tzinfo=TzInfo(0)), updated_at=datetime.datetime(2026, 5, 25, 7, 17, 10, 658000, tzinfo=TzInfo(0)), file_size_limit=None, allowed_mime_types=None, type='STANDARD')]

# %%
bucket = supabase.storage.from_("my-bucket-2")

# %%
file_path = "test.txt"

with open(file_path, "rb") as f:
    res = bucket.upload(
        path="uploads/test.txt",
        file=f,
        file_options={"content-type": "text/plain"}
    )

# %%
print(res)
# Out:
# UploadResponse(path='uploads/test.txt', full_path='my-bucket-2/uploads/test.txt', fullPath='my-bucket-2/uploads/test.txt')

# %%
res = bucket.download("uploads/test.txt")
with open("downloaded_test.txt", "wb") as f:
    f.write(res)

# %%
url = bucket.get_public_url("uploads/test.txt")
print(url)
# Out:
# https://xiqtgfcprxeqipvvyewe.supabase.co/storage/v1/object/public/my-bucket-2/uploads/test.txt

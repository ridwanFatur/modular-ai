# %%
from sqlalchemy import create_engine, String, Integer, ForeignKey
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column, relationship, sessionmaker

# %%
from models import Base, Account, HistoryChat

# %%
DATABASE_URL = "sqlite:///chat_app.db"
engine = create_engine(DATABASE_URL, echo=True)
SessionLocal = sessionmaker(bind=engine)

# %%
def init_db():
    Base.metadata.create_all(bind=engine)

# %%
init_db()
# Out:
# 2026-05-22 18:05:45,278 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-22 18:05:45,281 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("accounts")
# 2026-05-22 18:05:45,282 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-22 18:05:45,288 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("accounts")
# 2026-05-22 18:05:45,290 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-22 18:05:45,294 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("history_chats")
# 2026-05-22 18:05:45,296 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-22 18:05:45,298 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("history_chats")
# 2026-05-22 18:05:45,300 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-22 18:05:45,302 INFO sqlalchemy.engine.Engine
# CREATE TABLE accounts (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-05-22 18:05:45,305 INFO sqlalchemy.engine.Engine [no key 0.00276s] ()
# 2026-05-22 18:05:45,345 INFO sqlalchemy.engine.Engine
# CREATE TABLE history_chats (
# 	id INTEGER NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	content VARCHAR NOT NULL,
# 	user_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(user_id) REFERENCES accounts (id)
# )
#
#
# 2026-05-22 18:05:45,346 INFO sqlalchemy.engine.Engine [no key 0.00079s] ()
# 2026-05-22 18:05:45,364 INFO sqlalchemy.engine.Engine COMMIT
